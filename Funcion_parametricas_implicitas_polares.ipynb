# %% [markdown]
# <a href="https://colab.research.google.com/github/jenaroolmos/curso/blob/main/Funcion_parametricas_implicitas_polares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import sin, symbols, Abs, ln
from sympy.plotting import plot
def f(x):
  return .1*(x + 3 )*(x - 2)*(x + 4)

def g(x):
  return ln(x)

x = symbols('x')

g1 = plot(f(x), (x, -5, 5), line_color='red', show=False)
g2 = plot(g(f(x)), (x, -5, 5), line_color='blue', show=False)
g1.append(g2[0])
#g1.extend(g2)
g1.show()

# %%
from sympy import sin, symbols, Abs, ln
from sympy.plotting import plot
def f(x):
  return .1*(x + 3 )*(x - 2)*(x + 4)

def g(x):
  return ln(x)

x = symbols('x')

g1 = plot(f(x), (x, -5, 5), line_color='red', show=False)
g2 = plot(g(f(x)), (x, -5, 5), line_color='blue', show=False)
g1.append(g2[0])
#g1.extend(g2)
g1.show()

# %%
from sympy import symbols,Integral,sin
from sympy.plotting import plot
x=symbols('x')
fx=0
for i in range (4):
  fx=fx+sin(1*x)
print(fx)
plot(fx)
# Out:
# 4*sin(x)

# %%
from sympy import  symbols, integrate,exp,oo
x=symbols('x')
print(integrate(exp(-x),(x,0,00)))
# Out:
# 0

# %%
from sympy import symbols,Integral,sin
x=symbols('x')
intsen=Integral(sin(x),(x,-1,1))
print('El resultado es: ',intsen.evalf())
# Out:
# El resultado es:  0.e-100

# %%
from sympy import symbols,sin, Abs
from sympy.plotting import plot
def f(x):
  return Abs(Abs(x)-1)
x=symbols('x')
plot(f(x))
plot(f(f(f(x))));
plot(f(x)*f(x),(x,-5,5),line_color='red')

# %%
from sympy import sin, symbols, Abs, ln
from sympy.plotting import plot
def f(x):
  return (x + 3 )*(x - 2)*(x + 4)

def g(x):
  return ln(x)

x = symbols('x')

plot(f(x))
plot(f(x), (x, -5, 3), line_color='red')
plot(g(f(x)))

# %%
from sympy import sin, symbols, Abs, ln, sqrt
from sympy.plotting import plot
def f(x):
  return sqrt(-x)

def g(x):
  return ln(x)

x = symbols('x')

plot(f(g(x)))
plot(g(f(x)))
plot(f(x)*g(x),(x,-1,1))

# %%
import math
from sympy import sin, symbols, diff
from sympy.plotting import plot
suma=0
for n in range(1,100):
  suma=suma+((sin(2*np.pi*n**2*x)/4*np.pi**2*n**5)+x**2/2*n)

print(suma)
dx=diff(suma,x)
plot(dx,(x,-0.001,0.001))
# Out:
# 2475*x**2 + 2.46740110027234*sin(6.28318530717959*x) + 78.9568352087149*sin(25.1327412287183*x) + 599.578467366179*sin(56.5486677646163*x) + 2526.61872667888*sin(100.530964914873*x) + 7710.62843835106*sin(157.07963267949*x) + 19186.5109557177*sin(226.194671058465*x) + 41469.6102922772*sin(307.8760800518*x) + 80851.799253724*sin(402.123859659494*x) + 145697.567569981*sin(508.938009881546*x) + 246740.110027234*sin(628.318530717959*x) + 397377.414599961*sin(760.26542216873*x) + 613968.
.9173528852*x) + 6256158102.51084*sin(36291.6783342693*x) + 6678722207.18154*sin(37253.0056862678*x) + 7123817212.2813*sin(38226.8994088806*x) + 7592332344.49264*sin(39213.3595021078*x) + 8085179925.3724*sin(40212.3859659494*x) + 8603295667.43983*sin(41223.9788004053*x) + 9147638970.26475*sin(42248.1380054755*x) + 9719193216.55566*sin(43284.8635811602*x) + 10318966068.2479*sin(44334.1555274592*x) + 10947989762.5918*sin(45396.0138443725*x) + 11607321408.2408*sin(46470.4385319002*x) + 12298043281.3393*sin(47557.4295900423*x) + 13021263121.6115*sin(48656.9870187987*x) + 13778114428.4488*sin(49769.1108181695*x) + 14569756756.9981*sin(50893.8009881546*x) + 15397376014.2505*sin(52031.0575287542*x) + 16262184755.1285*sin(53180.880439968*x) + 17165422478.5749*sin(54343.2697217962*x) + 18108355923.6406*sin( ...

# %%
from sympy import sin, symbols, Abs
from sympy.plotting import plot
def f(x):
  return Abs(Abs(x) - 1)
x = symbols('x')

plot(f(x))
plot(f(f(f(x))));
plot(f(x)*f(x), (x, -5, 5), line_color='red')

# %%
from sympy  import symbols,Eq
from sympy import plot_implicit
x,y =symbols('x y')
plot_implicit(Eq(x**4-(x**2-y**3),0),(x,-1.5,1.5),(y,-1.5,1.5))

# %%
from sympy  import symbols,Eq
from sympy import plot_implicit
x,y =symbols('x y')
plot_implicit(Eq(x**4-(x**2-y**3),0),(x,-1.5,1.5),(y,-1.5,1.5))

# %%
from sympy import plot_implicit
from sympy import sqrt,sin
plot_implicit(sin(x**5)+(x-2*y**2)>0,(x,-2,4),(y,0,2));

# %% [markdown]
# Funciones Implicitas.

# %%
from sympy import symbols,Eq
from sympy import plot_implicit
x,y=symbols('x y')
plot_implicit(Eq(x**4-(x**2-y**3),0),(x,-1.5,1.5),(y,-1.5,1.5));

# %%
from sympy import plot_implicit
from sympy import sqrt,sin
plot_implicit(sin(x**5)+(x-2*y**2)>0,(x,-2,4),(y,0,2));

# %% [markdown]
# Actividad graficar la función implicita

# %%
from sympy import symbols,Eq
from sympy import plot_implicit
x,y=symbols('x y')
plot_implicit(Eq(x**2-y**2-2*y-3,0),(x,-4,4),(y,-2,2));

# %%
from sympy import plot_implicit
from sympy import sqrt,sin
plot_implicit(x**2-y**2-2*y-3,(x,-4,4),(y,-2,2));

# %%
from sympy import plot_implicit
plot_implicit((y+5/x**2)*(x-0.003)-9.7,(x,-2,8),(y,-2,20));

# %% [markdown]
# Funciones Parametricas

# %%
from sympy  import symbols,cos,sin,exp,pi
from sympy import plot_parametric
t=symbols('t')
def x(t):
  return sin(t)*(exp(cos(t))-2*cos(4*t)-sin(t/12)**5)
def y(t):
  return cos(t)*(exp(cos(t))-2*cos(4*t)-sin(t/12)**5)
plot_parametric(x(t),y(t),(t,-6*pi,6*pi));
plot_parametric(x(t),y(t), (t,-50,50))

# %%
from sympy  import symbols,cos,sin,pi
from sympy import plot_parametric
t=symbols('t')
def x(t):
  return cos(t)+(1/2)*cos(7*t)+(1/3)*sin(17*t)
def y(t):
  return sin(t)+(1/2)*sin(7*t)+(1/3)*cos(17*t)
plot_parametric(x(t),y(t),(t,0,14*pi));
plot_parametric(x(t),y(t), (t,-50,50))

# %% [markdown]
# Coordenadas Polares

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0,  2*np.pi, 1000)
r = np.sqrt(3*np.cos(2*theta))
x = r * np.cos(theta)
y = r * np.sin(theta)

plt.axis('off');
plt.axis('equal');
plt.title("Lemniscata")
plt.plot(x,y);
# Out:
# <ipython-input-28-5b548859d14f>:5: RuntimeWarning: invalid value encountered in sqrt
#   r = np.sqrt(3*np.cos(2*theta))

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2 * np.pi, 4000)
r = 3 * np.cos(6 * theta)
x = r * np.sin(theta)
y = r * np.cos(theta)

plt.axis('off');
plt.axis('equal');
plt.plot(x,y);

# %%
import numpy  as np
import matplotlib.pyplot as plt
theta=np.linspace(1,4*np.pi,4000)
r=np.sqrt(np.abs(3*np.cos(6*theta)))
plt.polar(theta,r,marker='+',color=(.2,.4,.5,.3));
plt.title('Leminiscata')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(1, 4 * np.pi, 4000)
r = np.sqrt(3 * np.cos(2 * theta))

plt.polar(theta, r, marker='+',color=(.2,.4,.5,.3) );
plt.title("Lemniscata")
plt.show();
# Out:
# <ipython-input-54-47b38a04d7ae>:5: RuntimeWarning: invalid value encountered in sqrt
#   r = np.sqrt(3 * np.cos(2 * theta))

# %%
import numpy as np
import matplotlib.pyplot as plt
theta=np.linspace(0,2*np.pi,4000)
r=3*np.cos(6*theta)
x=r*np.sin(theta)
y=r*np.cos(theta)
plt.axis('off');
plt.axis('equal');
plt.plot(x,y);

# %%
import numpy  as np
import matplotlib.pyplot as plt
theta=np.linspace(1,4*np.pi,4000)
r=np.sqrt(np.abs(3*np.cos(6*theta)))
plt.polar(theta,r,marker='+',color=(.2,.4,.5,.3));
plt.title('Leminiscata')
plt.show()

# %%
Actividad
graficar la cardiodiode

# %%
import numpy  as np
import matplotlib.pyplot as plt
theta=np.linspace(0,4*np.pi,4000)
r=3*(1+np.cos(theta))
x=r*np.sin(theta)
y=r*np.cos(theta)
plt.polar(theta,r,marker='+',color=(.2,.4,.5,.3));
plt.title('Cardiode')
plt.plot (x,y);

# %%
import numpy as np
import matplotlib.pyplot as plt
theta=np.linspace(0,2*np.pi,4000)
r=3*np.cos(6*theta)
x=r*np.sin(theta)
y=r*np.cos(theta)
plt.axis('off');
plt.axis('equal');
plt.plot(x,y);

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(1, 4 * np.pi, 4000)
r = 3*(1+np.cos(theta))

plt.polar(theta, r, marker='+',color=(.2,.4,.5,.3) );
plt.title("Cardioide")
plt.show();

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection='polar')
r = np.arange(0, 1, 0.001)
theta = 2 * 2*np.pi * r
line, = ax.plot(theta, r, color='#ee8d18', lw=1)

plt.show()
